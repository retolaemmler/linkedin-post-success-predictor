# %%
# %pip install numpy pandas scikit-learn sentence-transformers
# Out:
# Collecting numpy
#   Using cached numpy-2.4.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting pandas
#   Downloading pandas-3.0.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rlaemmler/Downloads/Transferarbeit/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.0.0-py3-none-any.whl.metadata (37 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.3.5-py3-none-any.whl.metadata (13 kB)
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from pathlib import Path
import pandas as pd
import regex 
import unicodedata

from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# Path to your data folder
DATA_ROOT = Path("../data") 
OUTPUT_FILE = "../data/Raw_Dataset_LinkedIn.csv"

COLUMN_ORDER = [
    # identifiers
    "User ID",
    "Profile Summary",
    "Post URL",
    "Post Timestamp DT",

    # content
    "Post Content",
    "Post Content Length",
    "Hook Length",
    "Emoji Count",
    "Hashtag Count",
    "Linebreak Count",
    "Link Count",
    "Semantic Alignment",
    "Sentiment Score",

    # media
    "Has Image",
    "Has Video",

    # network & activity
    "Network Size",

    # time features
    "Hour",
    "Day Of Week",

    # targets
    "Engagement Score",
    "Relative Engagement",
    "Is High Performing",
]

# %%
# Robust date parser for LinkedIn date formats
def robust_date_parser(series):
    # Try multiple formats to parse LinkedIn dates correctly.
    # List of formats possible in LinkedIn data
    formats = [
        '%d.%b.%y',          # 15.Dec.25
        '%Y-%m-%d %H:%M:%S', # 2025-12-16 09:19:30
        '%d.%m.%Y %H:%M',    # 12.12.2025 15:26
        '%m/%d/%Y %H:%M:%S'  # Potential US format
    ]
    
    parsed = pd.to_datetime(series, format='mixed', errors='coerce') # Try default first
    
    for fmt in formats:
        mask = parsed.isna()
        if not mask.any(): break
        parsed[mask] = pd.to_datetime(series[mask], format=fmt, errors='coerce')
        
    return parsed

# Processes one individual data folder and returns a DataFrame.
def process_single_user(folder):
    shares_path = folder / "Shares.csv"
    conn_path = folder / "Connections.csv"
    profile_path = folder / "Profile.csv"

    if not (shares_path.exists() and conn_path.exists()):
        return None

    # Load Connections and calculate Network Size growth
    df_conn = pd.read_csv(conn_path)
    df_conn['Connected On DT'] = robust_date_parser(df_conn['Connected On'])
    df_conn = df_conn.dropna(subset=['Connected On DT']).sort_values('Connected On DT')
    df_conn['Network Size'] = range(1, len(df_conn) + 1)

    # Load Shares
    df_shares = pd.read_csv(shares_path)
    df_shares['Post Timestamp DT'] = robust_date_parser(df_shares['Post Timestamp'])
    df_shares = df_shares.dropna(subset=['Post Timestamp DT']).sort_values('Post Timestamp DT')

    # Merge Network Size at the exact time of each post
    df_merged = pd.merge_asof(
        df_shares, 
        df_conn[['Connected On DT', 'Network Size']],
        left_on='Post Timestamp DT', 
        right_on='Connected On DT',
        direction='backward'
    )
    df_merged['Network Size'] = df_merged['Network Size'].fillna(1)

    # Calculate Engagement Score (Excluding Reposts as requested)
    df_merged['Likes'] = pd.to_numeric(df_merged['Likes'], errors='coerce').fillna(0)
    df_merged['Comments'] = pd.to_numeric(df_merged['Comments'], errors='coerce').fillna(0)
    df_merged['Engagement Score'] = (df_merged['Likes'] * 1) + (df_merged['Comments'] * 3)

    # Normalize (Relative Engagement per 1000 connections)
    df_merged['Relative Engagement'] = (df_merged['Engagement Score'] / df_merged['Network Size']) * 1000

    # Set Target Label (Success = Above User's Median)
    median_val = df_merged['Relative Engagement'].median()
    df_merged['Is High Performing'] = (df_merged['Relative Engagement'] > median_val).astype(int)

    # Add Profile Metadata for NLP
    if profile_path.exists():
        prof = pd.read_csv(profile_path)
        headline = str(prof['Headline'].iloc[0]) if not pd.isna(prof['Headline'].iloc[0]) else ""
        summary = str(prof['Summary'].iloc[0]) if not pd.isna(prof['Summary'].iloc[0]) else ""
        # df_merged['Profile Summary'] = f"{summary}"
        # df_merged['Profile Summary'] = f"{headline} {summary}"
        df_merged['Profile Summary'] = f"{headline} {summary}"
    else:
        df_merged['Profile Summary'] = ""

    df_merged['User ID'] = folder.name

    return df_merged

def count_visual_emoji(s: str) -> int:
    clusters = regex.findall(r"\X", str(s))
    return sum(
        1 for g in clusters
        if regex.search(r"\p{Extended_Pictographic}|\p{Regional_Indicator}", g)
    )

def count_links(text):
    if pd.isna(text):
        return 0
    # Matches most URL formats
    links = regex.findall(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', str(text))
    return len(links)


def add_additional_features(df):
    # Introduce new features based on Post Content
    df['Hook Length'] = df['Post Content'].apply(lambda x: len(str(x).split('\n')[0]))
    df["Emoji Count"] = df["Post Content"].apply(count_visual_emoji)
    df['Hashtag Count'] = df['Post Content'].apply(lambda x: len(regex.findall(r'#\w+', str(x))))
    df['Linebreak Count'] = df['Post Content'].apply(lambda x: str(x).count('\n'))
    df['Link Count'] = df['Post Content'].apply(count_links)
    df['Hour'] = df['Post Timestamp DT'].dt.hour
    df['Day Of Week'] = df['Post Timestamp DT'].dt.dayofweek # Monday=0, Sunday=6
    return df

def cleanup_data(df):
    original_count = len(df)
    print(f" - Original rows: {original_count}")

    # Deduplicate based on Post URL
    df = df.drop_duplicates(subset=['Post URL']).copy()
    print(f" - Rows after deduplication:  {len(df)}")

    # Remove unnecessary Has Document columns
    df.drop(columns=["Has Document"], inplace=True)

    # Introduce a feature post content length
    df['Post Content Length'] = df['Post Content'].str.len().fillna(0)

    # Filter out rows that are TRULY empty (NaN)
    df = df.dropna(subset=['Post Content']).copy()
 
    print(f"Cleanup complete:")
    print(f" - Original rows: {original_count}")
    print(f" - Cleaned rows:  {len(df)}")
    print(f" - Removed:       {original_count - len(df)}")

    return df

def arrange_columns_strict(df: pd.DataFrame, order: list[str]) -> pd.DataFrame:
    missing = [c for c in order if c not in df.columns]
    if missing:
        raise KeyError(f"Missing required columns: {missing}")
    return df[order].copy()

# %%
# Execute consolidation and feature engineering
all_results = []

if DATA_ROOT.exists():
    for folder in DATA_ROOT.iterdir():
        if folder.is_dir():
            #print(f"Recreating data for: {folder.name}...")
            df = process_single_user(folder)
            if df is not None:
                all_results.append(df)

if all_results:
    # Concatenate all user data into one Raw Master Dataset
    master_df = pd.concat(all_results, ignore_index=True)
    # Clean up data
    master_df = cleanup_data(master_df).copy()
    # Add additional features
    master_df = add_additional_features(master_df)

    print(f"User Breakdown:\n{master_df['User ID'].value_counts()}")
else:
    print("No data was found. Please ensure your folder structure is: /data/Name/Shares.csv")
# Out:
#  - Original rows: 10912
#  - Rows after deduplication:  10531
# Cleanup complete:
#  - Original rows: 10912
#  - Cleaned rows:  8542
#  - Removed:       2370
# User Breakdown:
# User ID
# Büşra Coşkuner       1053
# Marc Hauser             1049
# Michael Wood             973
# Jonas Kamber             650
# Andy Lavicka             442
# Laurent Decrue           438
# Reto Laemmler            436
# Oliver Ganz              372
# Tigran Arzumanov         341
# David Butler             305
# Sabine Wildemann         227
# Lisa Winter              207
# Tobias Clemens           165
# Valentin Binnendijk      159
# Dr. Martin Feuz          153
# Kateryna Osadchuk        144
# Beat Brun                138
# Andreas Stutz            133
# Arinda Huber-Bouman      126
# Theresa Engl             113
# Ksenija Korolova         103
# Tilman Eberle            103
# Joshua Steffen            98
# Michael Lanker            91
# Bernhard von Allmen       71
# Gerhard Wesp              65
# Philippe Theis            63
# Julien Silva              51
# René Goebels             42
# Martin Nyffenegger        40
# Patrick Fischbacher       37
# Stefan Birrer             33
# Thomas Veit               29
# Farhad Ahmadyar           16
# Daniel Grossenbacher      14
# Bernardo Romero           12
# Daniel Graf               10
# Yulia Matiash             10
# Oliver Notz                8
# Robin Setzer               8
# Michael Scheiwiller        7
# Alexander Rüegg           7
# Name: count, dtype: int64

# %%
# Load NLP Models for semantic and setiment analysis

print("Loading NLP Models...")

# Model for vector embeddings
semantic_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment", use_fast=False)
sentiment_model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")

# Sentiment analysis pipeline
sent_pipe = pipeline(
    "sentiment-analysis",
    model=sentiment_model,
    tokenizer=tokenizer,
    batch_size=32,       
    device=-1,
    top_k=None,
    truncation=True
)

print("Models loaded successfully.\n")
# Out:
# Loading NLP Models...
# Device set to use cpu
# Models loaded successfully.

# %%
# Helper functions semantic alignment and sentiment scores

def clean_text(text):
    if not isinstance(text, str) or pd.isna(text):
        return ""
    
    # Remove URLs (Standard regex)
    text = regex.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    
    # Remove Emojis & Symbols via Unicode Category
    # We keep: L (Letters), N (Numbers), P (Punctuation), Z (Spaces)
    # We remove: S (Symbols/Emojis), M (Marks/Accents that aren't letters)
    text = "".join(
        ch for ch in text 
        if unicodedata.category(ch)[0] in ['L', 'N', 'P', 'Z']
    )
    
    # Clean up Whitespace and Newlines
    text = text.replace('\n', ' ').replace('\r', ' ')
    text = regex.sub(r'\s+', ' ', text).strip()
    
    return text


def add_semantic_alignment(df):
    # Ensure all text is string and handle NaNs
    df['Post Content Clean'] = df['Post Content Clean'].fillna("").astype(str)
    df['Profile Summary Clean'] = df['Profile Summary Clean'].fillna("").astype(str)
    
    # Initialize the new column
    df['Semantic Alignment'] = 0.0
    
    # We process per user to be efficient (one profile vector vs many post vectors)
    unique_users = df['User ID'].unique()
    
    for user in unique_users:
        print(f"Calculating alignment for user: {user}")
        user_mask = df['User ID'] == user

        profile_text = df.loc[user_mask, 'Profile Summary Clean'].iloc[0]

        # 🚫 If profile summary empty → alignment = 0 for all posts
        if not isinstance(profile_text, str) or profile_text.strip() == "":
            df.loc[user_mask, 'Semantic Alignment'] = 0.0
            continue

        profile_embedding = semantic_model.encode(profile_text, convert_to_tensor=True)

        posts_text = df.loc[user_mask, 'Post Content Clean'].tolist()

        # Encode posts
        post_embeddings = semantic_model.encode(posts_text, convert_to_tensor=True)
        cosine_scores = util.cos_sim(profile_embedding, post_embeddings)[0].tolist()

        # 🚫 Force 0 if post content empty
        cosine_scores = [
            score if isinstance(text, str) and text.strip() != "" else 0.0
            for score, text in zip(cosine_scores, posts_text)
        ]

        df.loc[user_mask, 'Semantic Alignment'] = cosine_scores

    return df

def add_sentiment_score(text):
    if pd.isna(text) or str(text).strip() == "":
        return 0.0
    print(f"Calculating sentiment for text: {text[:30]}...")
    scores = sent_pipe(str(text))[0]
    # labels: 1..5 stars → map to [-1, +1]
    star = int(max(scores, key=lambda x: x["score"])["label"][0])
    return (star - 3) / 2

# %%
# Execution of semantic alignment and sentiment scoring
# Using cleaned text for semantic alignment
# Using original text for sentiment (includes icons etc.)

# Clean Post Content
master_df['Post Content Clean'] = master_df['Post Content'].apply(clean_text)
# Clean Profile Summary
master_df['Profile Summary Clean'] = master_df['Profile Summary'].apply(clean_text)

# Run vectorization
enriched_df = add_semantic_alignment(master_df)

# Add Sentiment Score
print("Calculating sentiment scores for all posts...")
enriched_df["Sentiment Score"] = enriched_df["Post Content"].apply(add_sentiment_score)

# Arrange columns
enriched_df = arrange_columns_strict(enriched_df, COLUMN_ORDER)

# Save the new version
enriched_df = arrange_columns_strict(enriched_df, COLUMN_ORDER)
enriched_df.sort_values(by=['User ID', 'Post Timestamp DT'], ascending=[True, False], inplace=True)
enriched_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSUCCESS: Enriched dataset saved to {OUTPUT_FILE}")

# Preview the results
print("Preview of sentiment score.")
print(enriched_df[['Post Content', 'Sentiment Score']].head())

print("\nPreview of top Alignment scores:")
print(enriched_df[['Post Content', 'Semantic Alignment']].sort_values(by='Semantic Alignment', ascending=False).head())
# Out:
# Calculating alignment for user: Bernardo Romero
# Calculating alignment for user: Valentin Binnendijk
# Calculating alignment for user: Michael Wood
# Calculating alignment for user: Tigran Arzumanov
# Calculating alignment for user: Dr. Martin Feuz
# Calculating alignment for user: Robin Setzer
# Calculating alignment for user: David Butler
# Calculating alignment for user: Tobias Clemens
# Calculating alignment for user: Lisa Winter
# Calculating alignment for user: Büşra Coşkuner
# Calculating alignment for user: Andreas Stutz
# Calculating alignment for user: Oliver Ganz
# Calculating alignment for user: Daniel Graf
# Calculating alignment for user: René Goebels
# Calculating alignment for user: Kateryna Osadchuk
# Calculating alignment for user: Jonas Kamber
# Calculating alignment for user: Oliver Notz
# Calculating alignment for user: Michael Scheiwiller
# Calculating alignment for user: Alexander Rüegg
# Calculating alignment for user: Philippe Theis
# Calculating alignment for user: Martin Nyffenegger
# Calculating alignment for user: Tilman Eberle
# Calculating alignment for user: Bernhard von Allmen
# Calculating alignment for user: Arinda Huber-Bouman
# Calculating alignment for user: Theresa Engl
# Calculating alignment for user: Stefan Birrer
# Calculating alignment for user: Sabine Wildemann
# Calculating alignment for user: Farhad Ahmadyar
# Calculating alignment for user: Andy Lavicka
# Calculating alignment for user: Yulia Matiash
# Calculating alignment for user: Patrick Fischbacher
# Calculating alignment for user: Joshua Steffen
# Calculating alignment for user: Beat Brun
# Calculating alignment for user: Daniel Grossenbacher
# Calculating alignment for user: Laurent Decrue
# Calculating alignment for user: Gerhard Wesp
# Calculating alignment for user: Reto Laemmler
# Calculating alignment for user: Thomas Veit
# Calculating alignment for user: Marc Hauser
# Calculating alignment for user: Ksenija Korolova
# Calculating alignment for user: Julien Silva
# Calculating alignment for user: Michael Lanker
# Calculating sentiment scores for all posts...
# Calculating sentiment for text: Liebes Netzwerk,
#
# Ich brauche...
# Calculating sentiment for text: Later today, a great chance to...
# Calculating sentiment for text: Year after year a great read....
# Calculating sentiment for text: Americas Market Intelligence s...
# Calculating sentiment for text: Are you an Expert in Water Sup...
# Calculating sentiment for text: Great opportunity for a Latam/...
# Calculating sentiment for text: Wie wäre es, diese freie Zeit ...
# Calculating sentiment for text: Achtung Zürich: eine spannende...
# Calculating sentiment for text: Offene Stelle: Digital Analyst...
# Calculating sentiment for text: This is a great opportunity fo...
# Calculating sentiment for text: Eine spannende Stelle im Data ...
# Calculating sentiment for text: Christina Meyer is #hiring. Kn...
# Calculating sentiment for text: I will be at SaaStr Europe 201...
# Calculating sentiment for text: What a ride it has been! Thank...
# Calculating sentiment for text: Interesse mit Marc und mir uns...
# Calculating sentiment for text: Congrats Nicolas and Jodok!...
# Calculating sentiment for text: Automatisiert personalisierte ...
# Calculating sentiment for text: Wie setzt ihr als B2B Unterneh...
# Calculating sentiment for text: Unsere Studie zu Marketing Aut...
# Calculating sentiment for text: It's official 🚀 Marc Gasser un...
# Calculating sentiment for text: Great to have you on board!...
# Calculating sentiment for text: Mitten auf unserer Reise dem M...
# Calculating sentiment for text: Der Marketing Automation Repor...
# Calculating sentiment for text: At Aioma we work with a remote...
# Calculating sentiment for text: Content ist wichtig. Engagemen...
# Calculating sentiment for text: Wie wir Content mit AI machen ...
# Calculating sentiment for text: Thank you Spicehaus Partners A...
# Calculating sentiment for text: Letztes Jahr haben wir mit uns...
# Calculating sentiment for text: Der meiste Content wird in Zuk...
# Calculating sentiment for text: Der Marketing Automation Repor...
# Calculating sentiment for text: Mitmachen am Marketing Automat...
# Calculating sentiment for text: What a ride it has been and st...
# Calculating sentiment for text: Die neuste Auflage des Marketi...
# Calculating sentiment for text: Check out the new book of my c...
# Calculating sentiment for text: Der neue Marketing Automation ...
# Calculating sentiment for text: Erster Sneak Peak! https://bit...
# Calculating sentiment for text: Finally, die erste Folge meine...
# Calculating sentiment for text: Die zweite Folge unseres Podca...
# Calculating sentiment for text: Post by Valentin Binnendijk...
# Calculating sentiment for text: "Sag nein zu Features, sag nei...
# Calculating sentiment for text: B2B Kunden finden, die wirklic...
# Calculating sentiment for text: Ein B2B Saas Produkt bauen. Li...
# Calculating sentiment for text: Wie werde ich Chef einer Money...
# Calculating sentiment for text: Mein Co-Founder Marc Gasser fü...
# Calculating sentiment for text: Statt Hardcore Outbound E-Mail...
# Calculating sentiment for text: Mega cool, dass es gelingt, di...
# Calculating sentiment for text: Morgen hast du die Chance Bjoe...
# Calculating sentiment for text: Ständig geht etwas schief: Man...
# Calculating sentiment for text: Die Marketing Automation 2023 ...
# Calculating sentiment for text: Wie setzt du dein B2B Schiff ⛵...
# Calculating sentiment for text: Ich baue ein neues 📦  Produkt ...
# Calculating sentiment for text: Wie findest du grossartige 👩‍🚀...
# Calculating sentiment for text: "Smells Like This Meeting Coul...
# Calculating sentiment for text: Are there other fellow🇨🇭entrep...
# Calculating sentiment for text: 4 takeaways from my 4th SaaStr...
# Calculating sentiment for text: Exciting news! 🚀 Building star...
# Calculating sentiment for text: We are launching our product o...
# Calculating sentiment for text: We are back 🎙️ #Podcast #Summe...
# Calculating sentiment for text: Wir haben bereits über 150 Anm...
# Calculating sentiment for text: Wir haben unser neues Produkt ...
# Calculating sentiment for text: Es ist immer das gleiche im B2...
# Calculating sentiment for text: 7 Tipps, wie man mehr Engageme...
# Calculating sentiment for text: How can you do effective B2B m...
# Calculating sentiment for text: Behind the scenes of building ...
# Calculating sentiment for text: After the pandemic, I thought ...
# Calculating sentiment for text: Remember the Yellow Pages or t...
# Calculating sentiment for text: Building a startup is like a r...
# Calculating sentiment for text: The answer to build a great pr...
# Calculating sentiment for text: Visual thinking trumps written...
# Calculating sentiment for text: Contrary to popular belief, hi...
# Calculating sentiment for text: What do a penguin 🐧 and your c...
# Calculating sentiment for text: Squeeze out all we know - tomo...
# Calculating sentiment for text: There are 3 types of content t...
# Calculating sentiment for text: To build a top-tier team, ⚙️ i...
# Calculating sentiment for text: “You guys are just brutally ho...
# Calculating sentiment for text: Leonardo da Vinci was a procra...
# Calculating sentiment for text: How to kill your productivity ...
# Calculating sentiment for text: I've met Christian over 15 yea...
# Calculating sentiment for text: The real question isn't what w...
# Calculating sentiment for text: "Have you met Ted?" - How Barn...
# Calculating sentiment for text: How fast can you grow?
# "As fas...
# Calculating sentiment for text: The eucalyptus tree 🌴 cut the ...
# Calculating sentiment for text: How would a product-led growth...
# Calculating sentiment for text: B2B is still driven by network...
# Calculating sentiment for text: Want to get some exclusive res...
# Calculating sentiment for text: Merry Christmas to Everyone 🎄
# ...
# Calculating sentiment for text: Happy New Year! 🎉
#
# Instead of ...
# Calculating sentiment for text: Knock, knock...
# Who's there?
# A...
# Calculating sentiment for text: January as an entrepreneur is ...
# Calculating sentiment for text: What is the single biggest suc...
# Calculating sentiment for text: Does your Sales Development Re...
# Calculating sentiment for text: To be successful in B2B Market...
# Calculating sentiment for text: We got 3 new clients from 2 Li...
# Calculating sentiment for text: After over 30 podcasts, my top...
# Calculating sentiment for text: How can you use an effective l...
# Calculating sentiment for text: Last week I was able to witnes...
# Calculating sentiment for text: Step-by-step guide for hyper-p...
# Calculating sentiment for text: How can you publish your own b...
# Calculating sentiment for text: The key to a successful market...
# Calculating sentiment for text: "Follow Guy Kawasaki's 18-poin...
# Calculating sentiment for text: Why in-person team meetings ar...
# Calculating sentiment for text: How do you create a target lis...
# Calculating sentiment for text: Iterate fast or die! ☠️ As ear...
# Calculating sentiment for text: The art of attracting people t...
# Calculating sentiment for text: Morgen wird der neuste Marketi...
# Calculating sentiment for text: Events are again the new black...
# Calculating sentiment for text: Endlich können wir den neuen M...
# Calculating sentiment for text: About quitting things that don...
# Calculating sentiment for text: Mein Co-Founder Marc Gasser er...
# Calculating sentiment for text: How do you deal with legacy co...
# Calculating sentiment for text: The destination website of the...
# Calculating sentiment for text: “Software is not eating everyt...
# Calculating sentiment for text: Sales efficiency is the key mo...
# Calculating sentiment for text: Panem et Circenses 🥖🎪!
#
# (Bread...
# Calculating sentiment for text: My career so far: I always hav...
# Calculating sentiment for text: So what can you do when you ha...
# Calculating sentiment for text: A masterclass in how to host g...
# Calculating sentiment for text: In less than two weeks, Saastr...
# Calculating sentiment for text: Lack of urgency is a killer fo...
# Calculating sentiment for text: Usually, you're too small to h...
# Calculating sentiment for text: Tomorrow I'm flying to the bes...
# Calculating sentiment for text: The best way to get inspired i...
# Calculating sentiment for text: Back from my favorite conferen...
# Calculating sentiment for text: To win in life means you have ...
# Calculating sentiment for text: Kommt jetzt diese KI-Revolutio...
# Calculating sentiment for text: Finding the perfect balance be...
# Calculating sentiment for text: People ask me sometimes: "You'...
# Calculating sentiment for text: Perhaps a look at your CRM rem...
# Calculating sentiment for text: What will it take to deliver d...
# Calculating sentiment for text: Having children made me think ...
# Calculating sentiment for text: How can you manage a product a...
# Calculating sentiment for text: My typical impulse buys on Ins...
# Calculating sentiment for text: I remember the first time we u...
# Calculating sentiment for text: My generation has invented soc...
# Calculating sentiment for text: Being efficient is often a mat...
# Calculating sentiment for text: Artificial intelligence has ve...
# Calculating sentiment for text: Founder Mode will be a conveni...
# Calculating sentiment for text: Mein Geschäftspartner Marc war...
# Calculating sentiment for text: Creating digital products has ...
# Calculating sentiment for text: The most important driver of p...
# Calculating sentiment for text: The magic word for B2B markete...
# Calculating sentiment for text: Next week I will be in Lisbon ...
# Calculating sentiment for text: Small teams developing digital...
# Calculating sentiment for text: How to build AI use cases 🤖 th...
# Calculating sentiment for text: Not drowning in the chaos of o...
# Calculating sentiment for text: A new chapter begins: I've joi...
# Calculating sentiment for text: I've had a few relationships w...
# Calculating sentiment for text: If things are moving fast, you...
# Calculating sentiment for text: How do you succeed as a produc...
# Calculating sentiment for text: To thrive in this fast-paced w...
# Calculating sentiment for text: The solution is a strong produ...
# Calculating sentiment for text: Too many requests. Too many to...
# Calculating sentiment for text: Uncertainty is the new normal....
# Calculating sentiment for text: The world is going AI-first 🤖....
# Calculating sentiment for text: A3F Conference by Alan in Züri...
# Calculating sentiment for text: Build better teams — one focus...
# Calculating sentiment for text: 🦁🐒🦓🦜 Product management in a v...
# Calculating sentiment for text: 🚧👷💻 Building a market leader i...
# Calculating sentiment for text: So I finally tried this “vibe ...
# Calculating sentiment for text: There’s no retirement for ambi...
# Calculating sentiment for text: The vibe is back. 🤖⚡️
#
# Today a...
# Calculating sentiment for text: This still feels like the AI h...
# Calculating sentiment for text: All-hands calls don’t build cu...
# Calculating sentiment for text: Remember: An AI already built ...
# Calculating sentiment for text: AI Agents: From Hype to Real W...
# Calculating sentiment for text: 996 or 9-to-5? Everyone’s got ...
# Calculating sentiment for text: Roll-ups, reality checks and t...
# Calculating sentiment for text: SaaStr.ai AI London 🇬🇧: The Sa...
# Calculating sentiment for text: Reflections on another AI hype...
# Calculating sentiment for text: AI Is Coming for Existing Lega...
# Calculating sentiment for text: The new programming language i...
# Calculating sentiment for text: Thank you for sharing Business...
# Calculating sentiment for text: Business Recipes Thanks for th...
# Calculating sentiment for text: Need to get and keep more prof...
# Calculating sentiment for text: Business Recipes supports this...
# Calculating sentiment for text: Business Recipes providing vit...
# Calculating sentiment for text: Business Recipes supports posi...
# Calculating sentiment for text: https://lnkd.in/g2JhWa5...
# Calculating sentiment for text: Business Recipes supports this...
# Calculating sentiment for text: When it comes to 'Cold Call/Ha...
# Calculating sentiment for text: Business Recipes  found this h...
# Calculating sentiment for text: Gary Compaan recommends this....
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Sometimes stating the obvious,...
# Calculating sentiment for text: Business Recipes...
# Calculating sentiment for text: @Business Recipes https://lnkd...
# Calculating sentiment for text: https://lnkd.in/g2r37nH...
# Calculating sentiment for text: https://lnkd.in/guiay3G Busine...
# Calculating sentiment for text: Exporting in Africa https://ln...
# Calculating sentiment for text: Next level of convenience and ...
# Calculating sentiment for text: Business Recipes...
# Calculating sentiment for text: https://lnkd.in/gjWWpHu Busine...
# Calculating sentiment for text: https://lnkd.in/gwMDH-R Busine...
# Calculating sentiment for text: It is all about perspective. I...
# Calculating sentiment for text: https://lnkd.in/gmkHnWU) Has a...
# Calculating sentiment for text: https://lnkd.in/gsE7aEP Can yo...
# Calculating sentiment for text: Good advice for salespeople, t...
# Calculating sentiment for text: Keep an eye on Africa! https:/...
# Calculating sentiment for text: https://lnkd.in/gmwH3gc Busine...
# Calculating sentiment for text: https://lnkd.in/gaATuXi Finall...
# Calculating sentiment for text: The best way brands can manage...
# Calculating sentiment for text: https://lnkd.in/gzXdFRu Busine...
# Calculating sentiment for text: Water crisis in Cape Town. Cos...
# Calculating sentiment for text: Thanks Eli Hochberg. Perceptio...
# Calculating sentiment for text: https://lnkd.in/g67kRfp Busine...
# Calculating sentiment for text: https://lnkd.in/gGDfURY level ...
# Calculating sentiment for text: CEOs are ultimately accountabl...
# Calculating sentiment for text: Get involved in the Cape Town ...
# Calculating sentiment for text: When selling and negotiating y...
# Calculating sentiment for text: https://lnkd.in/ggmJjCT #clien...
# Calculating sentiment for text: 80% of defecting clients descr...
# Calculating sentiment for text: https://lnkd.in/g6byz86 ... so...
# Calculating sentiment for text: https://lnkd.in/gPwR5cZ...
# Calculating sentiment for text: https://lnkd.in/ecEpvBE...
# Calculating sentiment for text: For every client that complain...
# Calculating sentiment for text: Congratulations Mr. President....
# Calculating sentiment for text: https://lnkd.in/gX_yBiP...
# Calculating sentiment for text: How many views, tweets, likes,...
# Calculating sentiment for text: There is no such thing as neut...
# Calculating sentiment for text: https://lnkd.in/gWq5YE5...
# Calculating sentiment for text: https://lnkd.in/g8JxnZq...
# Calculating sentiment for text: https://lnkd.in/gAH24rp...
# Calculating sentiment for text: Great initiative. Does anyone ...
# Calculating sentiment for text: If you, your brand or offering...
# Calculating sentiment for text: https://lnkd.in/gKpFzcH On-lin...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #Selling vs. #Negotiation It i...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/em22snS #marke...
# Calculating sentiment for text: You can embrace it, contribute...
# Calculating sentiment for text: https://lnkd.in/e_idyF5 #recyc...
# Calculating sentiment for text: The African Development Bank w...
# Calculating sentiment for text: How is your Strategic Planning...
# Calculating sentiment for text: https://lnkd.in/dxecBF8...
# Calculating sentiment for text: https://lnkd.in/esu_JNH #crypt...
# Calculating sentiment for text: https://lnkd.in/euDgJwP #AI #C...
# Calculating sentiment for text: https://lnkd.in/efPB4Ka #CX #c...
# Calculating sentiment for text: https://lnkd.in/eirq9GC #AI...
# Calculating sentiment for text: https://lnkd.in/eRuTV4b #Enter...
# Calculating sentiment for text: https://lnkd.in/eVCKiuq...
# Calculating sentiment for text: Well put Gary. Nail on the hea...
# Calculating sentiment for text: https://lnkd.in/dcudYFm...
# Calculating sentiment for text: https://lnkd.in/diDSU4T...
# Calculating sentiment for text: https://lnkd.in/eFPwBDt #decis...
# Calculating sentiment for text: The last 60 minutes of your on...
# Calculating sentiment for text: https://lnkd.in/drnMu9z...
# Calculating sentiment for text: https://lnkd.in/e27z9Gs...
# Calculating sentiment for text: https://lnkd.in/eUS3im6 #afric...
# Calculating sentiment for text: https://lnkd.in/eA7twNd...
# Calculating sentiment for text: https://lnkd.in/gb_vJ5Y...
# Calculating sentiment for text: https://lnkd.in/gUFTs5J...
# Calculating sentiment for text: https://lnkd.in/euZw_pt...
# Calculating sentiment for text: https://lnkd.in/eUUYSYF...
# Calculating sentiment for text: https://lnkd.in/eWnFs8w...
# Calculating sentiment for text: https://lnkd.in/e9T5AYW...
# Calculating sentiment for text: https://lnkd.in/eSYFdip...
# Calculating sentiment for text: https://lnkd.in/grcFpUm #Autod...
# Calculating sentiment for text: https://lnkd.in/dBfVYe2...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: www.designnextafrica.com...
# Calculating sentiment for text: https://lnkd.in/dbPsfuZ...
# Calculating sentiment for text: https://lnkd.in/dy-kkqH...
# Calculating sentiment for text: Autodesk Student Design Compet...
# Calculating sentiment for text: https://lnkd.in/g9DrP9X...
# Calculating sentiment for text: https://lnkd.in/gtCz_s2...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eu9Zz85 #Ideat...
# Calculating sentiment for text: https://lnkd.in/gitsgvQ #const...
# Calculating sentiment for text: https://lnkd.in/dFF9kct #const...
# Calculating sentiment for text: https://lnkd.in/dc-CJZZ Regist...
# Calculating sentiment for text: #construction #3dmodeling #bui...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #construction #3dmodeling #bui...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #structuralengineering...
# Calculating sentiment for text: #construction #buildingdesign ...
# Calculating sentiment for text: https://lnkd.in/e6Px4_n #3dmod...
# Calculating sentiment for text: https://lnkd.in/ecBXmMD #3dmod...
# Calculating sentiment for text: #construction #buildingdesign ...
# Calculating sentiment for text: #3dmodeling...
# Calculating sentiment for text: #arcgis...
# Calculating sentiment for text: #autocad #bridge #3dmodeling #...
# Calculating sentiment for text: #machinelearning #structuralen...
# Calculating sentiment for text: #urbanization #socialresearch ...
# Calculating sentiment for text: http://au-africa.com/ #constru...
# Calculating sentiment for text: #3dmodeling #buildingdesign...
# Calculating sentiment for text: #3dmodeling...
# Calculating sentiment for text: #revit #3dmodeling  #buildingd...
# Calculating sentiment for text: #machinelearning #construction...
# Calculating sentiment for text: #3dmodeling...
# Calculating sentiment for text: https://lnkd.in/e3fjAxa #const...
# Calculating sentiment for text: #3dmodeling #arcgis...
# Calculating sentiment for text: #3dmodeling #bim #autocad...
# Calculating sentiment for text: #autocad #3dmodeling  #designb...
# Calculating sentiment for text: #3dmodeling #designbuild #bim ...
# Calculating sentiment for text: #construction #buildings #auto...
# Calculating sentiment for text: #designbuild...
# Calculating sentiment for text: #construction #buildings #desi...
# Calculating sentiment for text: https://lnkd.in/ejutj2p #3dmod...
# Calculating sentiment for text: #machinelearning #artificialin...
# Calculating sentiment for text: #autocad #3dmodeling...
# Calculating sentiment for text: #bim #buildings #3dmodeling #d...
# Calculating sentiment for text: https://lnkd.in/e_w_W7x #const...
# Calculating sentiment for text: #construction  #bim  #building...
# Calculating sentiment for text: #buildings #bim #3dmodeling #d...
# Calculating sentiment for text: #bim #buildings #3dmodeling...
# Calculating sentiment for text: #bim #buildings #3dmodeling...
# Calculating sentiment for text: #artificialintelligence...
# Calculating sentiment for text: #bim #buildings #3dmodeling #d...
# Calculating sentiment for text: #bim #buildings #3dmodeling #a...
# Calculating sentiment for text: #channeldevelopment #marketing...
# Calculating sentiment for text: #bim #buildings #3dmodeling #d...
# Calculating sentiment for text: https://lnkd.in/ebQdBJ6 #bim #...
# Calculating sentiment for text: #bim #buildings #construction...
# Calculating sentiment for text: #bim #construction #autocad #3...
# Calculating sentiment for text: #africa #bim #autocad #3dmodel...
# Calculating sentiment for text: #bim #buildings #3dmodeling #p...
# Calculating sentiment for text: #bim #buildings #3dmodeling...
# Calculating sentiment for text: #bim #buildings #africa...
# Calculating sentiment for text: #construction #africa #bim #bu...
# Calculating sentiment for text: #bim #buildings #autocad...
# Calculating sentiment for text: https://lnkd.in/ew9FF9W #const...
# Calculating sentiment for text: https://lnkd.in/eifNusF...
# Calculating sentiment for text: #africa #bim #construction #3d...
# Calculating sentiment for text: #bim  #autocad  #buildings  #c...
# Calculating sentiment for text: https://lnkd.in/emgTsWN #bim #...
# Calculating sentiment for text: https://lnkd.in/ekYDsXE #const...
# Calculating sentiment for text: #construction #bim #buildings ...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #construction #africa #bim #3d...
# Calculating sentiment for text: #buildings #3dmodeling #buildi...
# Calculating sentiment for text: #connectedbim #africa #bim...
# Calculating sentiment for text: #construction #design #bim #bu...
# Calculating sentiment for text: #construction #bim #buildings ...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/exNxiZt #3dmod...
# Calculating sentiment for text: #construction #design #bim...
# Calculating sentiment for text: https://lnkd.in/efGNCBz #futur...
# Calculating sentiment for text: https://lnkd.in/dzh-vSC #infra...
# Calculating sentiment for text: #design #construction...
# Calculating sentiment for text: #future #construction #manufac...
# Calculating sentiment for text: https://lnkd.in/denCbGU #mobil...
# Calculating sentiment for text: #construction #artificialintel...
# Calculating sentiment for text: #geomatics #esri #geopositioni...
# Calculating sentiment for text: #construction #bim #geopositio...
# Calculating sentiment for text: https://lnkd.in/eXvV9uA #const...
# Calculating sentiment for text: https://lnkd.in/ekfqZCi #afric...
# Calculating sentiment for text: #machinelearning #future #arti...
# Calculating sentiment for text: #construction #infrastructure ...
# Calculating sentiment for text: https://lnkd.in/ehHATPe #entre...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #future #artificialintelligenc...
# Calculating sentiment for text: https://lnkd.in/eGEaHeg #techn...
# Calculating sentiment for text: #technology #economy #manufact...
# Calculating sentiment for text: #esri...
# Calculating sentiment for text: #technology #machinelearning #...
# Calculating sentiment for text: #technology #future #artificia...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #design #manufacturing...
# Calculating sentiment for text: https://lnkd.in/eFr2hck #3dmod...
# Calculating sentiment for text: #construction #infrastructure ...
# Calculating sentiment for text: https://lnkd.in/eNkjhpC #const...
# Calculating sentiment for text: https://lnkd.in/eSsTFfc #digit...
# Calculating sentiment for text: #design #technology #future #m...
# Calculating sentiment for text: #esri #autodesk...
# Calculating sentiment for text: https://lnkd.in/eHh4sGC #cloud...
# Calculating sentiment for text: #design #construction #bim...
# Calculating sentiment for text: #autocad #autodesksoftware #fu...
# Calculating sentiment for text: https://lnkd.in/ep3_gJe #artif...
# Calculating sentiment for text: #revit #esri #arcgis  #africa...
# Calculating sentiment for text: #design #construction #infrast...
# Calculating sentiment for text: https://lnkd.in/e7JArq7 #desig...
# Calculating sentiment for text: https://lnkd.in/eue3xQA #bim #...
# Calculating sentiment for text: #ideatetechnologies #worldsvie...
# Calculating sentiment for text: #3dprinting #future #miningdev...
# Calculating sentiment for text: #bim #fomt...
# Calculating sentiment for text: #construction #technology #ana...
# Calculating sentiment for text: https://lnkd.in/eTbPQh6 #techn...
# Calculating sentiment for text: #design...
# Calculating sentiment for text: https://lnkd.in/eySDCBz #const...
# Calculating sentiment for text: #bim #digitization #africa...
# Calculating sentiment for text: #design #technology #construct...
# Calculating sentiment for text: https://lnkd.in/eUqMjdV #bim #...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Drone Eyes in the Sky Can Save...
# Calculating sentiment for text: #africa #digitaltransformation...
# Calculating sentiment for text: #artificialintelligence #cyber...
# Calculating sentiment for text: https://lnkd.in/eGKRry3 #techn...
# Calculating sentiment for text: #construction #design #bim...
# Calculating sentiment for text: https://lnkd.in/ef6Gz6Q #digit...
# Calculating sentiment for text: #bim...
# Calculating sentiment for text: https://lnkd.in/egEPFfK #desig...
# Calculating sentiment for text: https://lnkd.in/efY3jFm #desig...
# Calculating sentiment for text: Autodesk Completes PlanGrid Ac...
# Calculating sentiment for text: https://lnkd.in/eER3_pm...
# Calculating sentiment for text: #design #construction #infrast...
# Calculating sentiment for text: https://lnkd.in/eT4jmuM #techn...
# Calculating sentiment for text: https://lnkd.in/ebxrPib #techn...
# Calculating sentiment for text: #design #construction  #bim...
# Calculating sentiment for text: https://lnkd.in/eNub5Ek #desig...
# Calculating sentiment for text: #design #construction #bim...
# Calculating sentiment for text: https://lnkd.in/erb-_fC #digit...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/d-R39TR #const...
# Calculating sentiment for text: https://lnkd.in/es7P2uz...
# Calculating sentiment for text: Free Research Report: The KPIs...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Team Africa at the Topcon Xper...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/ezNNqdZ...
# Calculating sentiment for text: https://lnkd.in/eG6QnNr...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eA_3YaN #const...
# Calculating sentiment for text: https://lnkd.in/eWwiJJ3 #marke...
# Calculating sentiment for text: #bim  #autodesk...
# Calculating sentiment for text: https://lnkd.in/etS8hMi #const...
# Calculating sentiment for text: #topcon #clearedge3d #worldsvi...
# Calculating sentiment for text: https://lnkd.in/ebmwsGw #geopo...
# Calculating sentiment for text: https://lnkd.in/edp3HSG #geopo...
# Calculating sentiment for text: #autodesk #topcon #worldsviewt...
# Calculating sentiment for text: https://lnkd.in/eutQuge #topco...
# Calculating sentiment for text: #surveying #topcon #ideatetech...
# Calculating sentiment for text: https://lnkd.in/emhX4mR...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #autodesk #topcon #worldsviewt...
# Calculating sentiment for text: https://lnkd.in/eTyfc_i #manuf...
# Calculating sentiment for text: #esri #bim #gis...
# Calculating sentiment for text: #ideatetechnologies #topcon #r...
# Calculating sentiment for text: https://lnkd.in/eJgj8mQ #const...
# Calculating sentiment for text: #topcon #geopositioning...
# Calculating sentiment for text: #autodesk #ideatetechnologies ...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/e4E8EEv #autod...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/ekTzVDu...
# Calculating sentiment for text: https://lnkd.in/e66uxQ4...
# Calculating sentiment for text: #topcon #paving #roads #worlds...
# Calculating sentiment for text: https://lnkd.in/epJc69G #water...
# Calculating sentiment for text: #construction #autodesk #afric...
# Calculating sentiment for text: https://lnkd.in/e-c7Pan #afric...
# Calculating sentiment for text: https://lnkd.in/e9ZQjxp #const...
# Calculating sentiment for text: #bim #construction...
# Calculating sentiment for text: https://lnkd.in/e3i3PHy #const...
# Calculating sentiment for text: https://lnkd.in/e8y-TuK...
# Calculating sentiment for text: #esri...
# Calculating sentiment for text: https://lnkd.in/eDUNERr #Topco...
# Calculating sentiment for text: https://lnkd.in/eXF3hvy #autod...
# Calculating sentiment for text: https://lnkd.in/eECmaRE #autod...
# Calculating sentiment for text: #topcon #geopositioning #ideat...
# Calculating sentiment for text: https://lnkd.in/e2_dsMK...
# Calculating sentiment for text: #bim #africa #buildingdesign #...
# Calculating sentiment for text: https://lnkd.in/etnPXT5 #autod...
# Calculating sentiment for text: #OD #changemangement...
# Calculating sentiment for text: https://lnkd.in/ewU-ZmY #afric...
# Calculating sentiment for text: https://lnkd.in/eFtgmFx #const...
# Calculating sentiment for text: https://lnkd.in/eQqHbdi...
# Calculating sentiment for text: https://lnkd.in/e8wx4H7 #esri...
# Calculating sentiment for text: https://lnkd.in/eSpqEf8...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eVJvxZ7 #const...
# Calculating sentiment for text: https://lnkd.in/eb7uacz...
# Calculating sentiment for text: https://lnkd.in/d-SU6sr...
# Calculating sentiment for text: https://lnkd.in/egzcXE8...
# Calculating sentiment for text: https://lnkd.in/ePuU5Xi #leadm...
# Calculating sentiment for text: https://lnkd.in/enYZHY9 #minin...
# Calculating sentiment for text: https://lnkd.in/em2-uy5 #techn...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eRGjx_B #techn...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #salesenablement #demandgenera...
# Calculating sentiment for text: https://lnkd.in/exWS6rG #b2bma...
# Calculating sentiment for text: https://lnkd.in/exs8Di2 #const...
# Calculating sentiment for text: #constructionsoftware #topcon ...
# Calculating sentiment for text: https://lnkd.in/esRmyT6...
# Calculating sentiment for text: https://lnkd.in/exhREp9...
# Calculating sentiment for text: https://lnkd.in/eMjFK35...
# Calculating sentiment for text: https://lnkd.in/e6Mnwvh...
# Calculating sentiment for text: https://lnkd.in/gnrgWMu #techn...
# Calculating sentiment for text: https://lnkd.in/edXxbfw...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eaAgJxY...
# Calculating sentiment for text: https://lnkd.in/eStXpMN...
# Calculating sentiment for text: https://lnkd.in/eyYx5aZ #chann...
# Calculating sentiment for text: https://lnkd.in/dBjEc9e #marke...
# Calculating sentiment for text: https://lnkd.in/dqJpQSp #afric...
# Calculating sentiment for text: #constructioninnovation #const...
# Calculating sentiment for text: https://lnkd.in/eSUCsKq #chann...
# Calculating sentiment for text: https://lnkd.in/eWJCmAE #leadm...
# Calculating sentiment for text: https://lnkd.in/eT9nSM6 #custo...
# Calculating sentiment for text: https://lnkd.in/euxQqd8 #diver...
# Calculating sentiment for text: https://lnkd.in/dFceDFa...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #topcon #ideatetechnologies #s...
# Calculating sentiment for text: https://lnkd.in/emK6df8...
# Calculating sentiment for text: https://lnkd.in/etXMmRR #chann...
# Calculating sentiment for text: https://lnkd.in/ei47ENe #chann...
# Calculating sentiment for text: https://lnkd.in/e4nzvV5 #locat...
# Calculating sentiment for text: https://lnkd.in/ec9c2dU #chann...
# Calculating sentiment for text: https://lnkd.in/ewNZtu2...
# Calculating sentiment for text: https://lnkd.in/e-_B24Y #chann...
# Calculating sentiment for text: https://lnkd.in/epXmWfm #chann...
# Calculating sentiment for text: https://lnkd.in/d2cKckf #chann...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eUXg6Qv...
# Calculating sentiment for text: https://lnkd.in/ei47ENe...
# Calculating sentiment for text: https://lnkd.in/erwA6_V #const...
# Calculating sentiment for text: https://lnkd.in/euHwPde...
# Calculating sentiment for text: https://lnkd.in/ebUcfgb #const...
# Calculating sentiment for text: https://lnkd.in/eqYz2Wn...
# Calculating sentiment for text: #constructionverfication #cons...
# Calculating sentiment for text: https://lnkd.in/eFKejgp #b2bma...
# Calculating sentiment for text: https://lnkd.in/e9php-y...
# Calculating sentiment for text: https://lnkd.in/dqJpQSp #afric...
# Calculating sentiment for text: https://lnkd.in/d7qMfHa #proje...
# Calculating sentiment for text: https://lnkd.in/emYHpxA...
# Calculating sentiment for text: https://lnkd.in/edYeVgc...
# Calculating sentiment for text: https://lnkd.in/d2S9cWK...
# Calculating sentiment for text: https://lnkd.in/dwSd3xY...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eg5TDur #marke...
# Calculating sentiment for text: https://lnkd.in/eQ-rA3B...
# Calculating sentiment for text: https://lnkd.in/dzn3wVh...
# Calculating sentiment for text: https://lnkd.in/d7a2anB...
# Calculating sentiment for text: https://lnkd.in/eRGjx_B #deman...
# Calculating sentiment for text: https://lnkd.in/ebnRbaU...
# Calculating sentiment for text: https://lnkd.in/eWwc5ut #conte...
# Calculating sentiment for text: https://lnkd.in/eMjg26R...
# Calculating sentiment for text: https://lnkd.in/epgHm9d #deman...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/eYtqMs7 #chann...
# Calculating sentiment for text: https://lnkd.in/esHGBFU # #b2b...
# Calculating sentiment for text: https://lnkd.in/eRir7vA #digit...
# Calculating sentiment for text: https://lnkd.in/erKaiyT #closi...
# Calculating sentiment for text: https://lnkd.in/eynWsBn...
# Calculating sentiment for text: # #...
# Calculating sentiment for text: https://lnkd.in/dJdxwCS #saas ...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Create Floor Plans Faster with...
# Calculating sentiment for text: Civil 3D et InfraWorks - Relie...
# Calculating sentiment for text: Find Construction Mistakes Bef...
# Calculating sentiment for text: https://lnkd.in/dVgSsYi...
# Calculating sentiment for text: Topcon Positioning Systems’ us...
# Calculating sentiment for text: Check Out EdgeWise's Improved ...
# Calculating sentiment for text: Manage a Smoother Process, Inc...
# Calculating sentiment for text: Obtain Dimensionally Accurate ...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/d8CdYRE...
# Calculating sentiment for text: https://lnkd.in/dCAbfFD...
# Calculating sentiment for text: https://lnkd.in/g72bqWz...
# Calculating sentiment for text: https://lnkd.in/dx_8-8M...
# Calculating sentiment for text: https://lnkd.in/dDeGZQF...
# Calculating sentiment for text: https://lnkd.in/d9jAQJ2...
# Calculating sentiment for text: The CWx – Africa Customer even...
# Calculating sentiment for text: Ready for better Civil 3D coll...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/dwFwdYE...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Automation in Africa  ...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: https://lnkd.in/dWWGVDs...
# Calculating sentiment for text: https://lnkd.in/dBhqhic...
# Calculating sentiment for text: https://lnkd.in/dPkrH6C...
# Calculating sentiment for text: https://lnkd.in/dWRgkif...
# Calculating sentiment for text: https://lnkd.in/dNXtTj6...
# Calculating sentiment for text: https://lnkd.in/dcPSzhF...
# Calculating sentiment for text: https://lnkd.in/dSWb8vY...
# Calculating sentiment for text: https://lnkd.in/dHsEVqB...
# Calculating sentiment for text: https://lnkd.in/dPAj-DY #ontwe...
# Calculating sentiment for text: #ontwerp #logodesign...
# Calculating sentiment for text: #ontwerp #contentmarketing #co...
# Calculating sentiment for text: No matter how many targeted pe...
# Calculating sentiment for text: Found this a useful read. #ont...
# Calculating sentiment for text: "You can't sell it, if you can...
# Calculating sentiment for text: #meaningfulconnections #meanin...
# Calculating sentiment for text: #contentmarketingtrends...
# Calculating sentiment for text: #ontwerp #contentmarketing #in...
# Calculating sentiment for text: I found this guide useful and,...
# Calculating sentiment for text: #logo #graphicdesign #monogram...
# Calculating sentiment for text: Just attended an insightful OD...
# Calculating sentiment for text: Looking forward to the feedbac...
# Calculating sentiment for text: Loved the movie. Great poster....
# Calculating sentiment for text: The goal of a user interface (...
# Calculating sentiment for text: Interesting. Not always what y...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: #branding #ontwerp #neutralbra...
# Calculating sentiment for text: #marketingcontent #ontwerp #co...
# Calculating sentiment for text: #ontwerp #contentrelevance #co...
# Calculating sentiment for text: #storytelling #brandvalue #ont...
# Calculating sentiment for text: #ontwerp #intentionalcommunica...
# Calculating sentiment for text: #ontwerp #connectedness #socia...
# Calculating sentiment for text: #ontwerp #contentgeneration #v...
# Calculating sentiment for text: Brands have value. Your person...
# Calculating sentiment for text: Interesting read. What are you...
# Calculating sentiment for text: A worthwhile read if you are i...
# Calculating sentiment for text: # brandstorytelling #brandvalu...
# Calculating sentiment for text: #brandvalue #brandstorytelling...
# Calculating sentiment for text: Being in the Marketing/Content...
# Calculating sentiment for text: #contentmarketingstrategy #con...
# Calculating sentiment for text: #imagemanagement #imageattribu...
# Calculating sentiment for text: Whats-up at WhatsApp? #textmes...
# Calculating sentiment for text: I found this useful and practi...
# Calculating sentiment for text: #financeandeconomy...
# Calculating sentiment for text: #customerrelations #reviews #t...
# Calculating sentiment for text: Acquiring data is the lessor c...
# Calculating sentiment for text: If you are, or are looking to ...
# Calculating sentiment for text: I found this very useful....
# Calculating sentiment for text: I found this a useful read and...
# Calculating sentiment for text: The quicker and the more effec...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Interesting. What do you think...
# Calculating sentiment for text: #dailypost #contentmarketingst...
# Calculating sentiment for text: "Of course, organizing a digit...
# Calculating sentiment for text: I have registered and I am loo...
# Calculating sentiment for text: I found this worth reading. #b...
# Calculating sentiment for text: #inboundmarketing #SEO...
# Calculating sentiment for text: Marketing is based on Science ...
# Calculating sentiment for text: Really looking forward to this...
# Calculating sentiment for text: I have registered and I am loo...
# Calculating sentiment for text: There are always three sides t...
# Calculating sentiment for text: Really looking forward to atte...
# Calculating sentiment for text: I have experienced this, or at...
# Calculating sentiment for text: #digitalliteracy #technology...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: Value points made here by Simo...
# Calculating sentiment for text: #financeandeconomy #fintech...
# Calculating sentiment for text: Post by Michael Wood...
# Calculating sentiment for text: I found the Tarsus Technology ...
# Calculating sentiment for text: "Influencer Marketing has earn...
# Calculating sentiment for text: "Phenomenal doesn’t begin to d...
# Calculating sentiment for text: How Your Language Shapes the W...
# Calculating sentiment for text: "There is more to building a S...
# Calculating sentiment for text: I'm attending SOUTH AFRICA: FU...
# Calculating sentiment for text: What do you think? #society #s...
# Calculating sentiment for text: Have we become too used to mod...
# Calculating sentiment for text: If you want to get started wit...
# Calculating sentiment for text: "Why did an articulate, intell...
# Calculating sentiment for text: Interesting that they call it ...
# Calculating sentiment for text: "Surfers say waves travel in g...
# Calculating sentiment for text: #vuca #bani...
# Calculating sentiment for text: #assetoptimization #efficiency...
# Calculating sentiment for text: I found this pretty useful....
# Calculating sentiment for text: "Neuromarketing studies provid...
# Calculating sentiment for text: I found this really interestin...
# Calculating sentiment for text: "You’re a smart B2B marketer, ...
# Calculating sentiment for text: "While it’s true that there ar...
# Calculating sentiment for text: I found this insightful. A goo...
# Calculating sentiment for text: I'm attending Free Webinar: Ho...
# Calculating sentiment for text: The new Swiss data protection ...
# Calculating sentiment for text: Just attended "How B2B Brands ...
# Calculating sentiment for text: #africatech #africanstartups #...
# Calculating sentiment for text: I'm attending Free Webinar: Th...
# Calculating sentiment for text: Mapped: The Fastest (and Slowe...
# Calculating sentiment for text: I found this insightful. #cont...
# Calculating sentiment for text: Are you addicted to your smart...
# Calculating sentiment for text: "In the post-Covid era, client...
# Calculating sentiment for text: "How do you do this? By puttin...
# Calculating sentiment for text: "New research from the Kellogg...
# Calculating sentiment for text: "To excite your leads, you mus...
# Calculating sentiment for text: "The key is to see that today’...
# Calculating sentiment for text: "Can Robotics actually improve...
# Calculating sentiment for text: "Measurement is fundamental to...
# Calculating sentiment for text: "Are you a non-native English ...
# Calculating sentiment for text: "All it takes is a good story ...
# Calculating sentiment for text: "As a marketing and communicat...
# Calculating sentiment for text: #b2bneuromarketing #b2bneuroma...
# Calculating sentiment for text: By Philip Kotler, Hermawan Kar...
# Calculating sentiment for text: I'm attending Neuromarketing C...
# Calculating sentiment for text: #storytelling #visualcommunica...
# Calculating sentiment for text: "A headless content management...
# Calculating sentiment for text: "Innovations, breakthroughs an...
# Calculating sentiment for text: "Identifying these habits will...
# Calculating sentiment for text: Check out this upcoming event ...
# Calculating sentiment for text: #interactivecontent #contentma...
# Calculating sentiment for text: "Before online influencer mark...
# Calculating sentiment for text: "If you want to build a succes...
# Calculating sentiment for text: "The new question becomes how ...
# Calculating sentiment for text: I'm attending International Ne...
# Calculating sentiment for text: "Why Business Storytelling mak...
# Calculating sentiment for text: Really enjoyed participating i...
# Calculating sentiment for text: "Creation of quality content i...
# Calculating sentiment for text: "In the world of digital marke...
# Calculating sentiment for text: "Data comes in many different ...
# Calculating sentiment for text: "Whether you’re crafting the p...
# Calculating sentiment for text: "Irrespective of the size of y...
# Calculating sentiment for text: "The words that accompany your...
# Calculating sentiment for text: "B2B content marketers say web...
# Calculating sentiment for text: "Data isn’t just used today to...
# Calculating sentiment for text: "Every story is different. Eve...
# Calculating sentiment for text: "As anyone who’s started a com...
# Calculating sentiment for text: "Companies spend more time and...
# Calculating sentiment for text: "People don’t care about your ...
# Calculating sentiment for text: "You can publish a steady stre...
# Calculating sentiment for text: "As with all your marketing ac...
# Calculating sentiment for text: "As content marketers, we ofte...
# Calculating sentiment for text: "Video, a powerful tool in the...
# Calculating sentiment for text: Which industries are embracing...
# Calculating sentiment for text: "The First (and the most impor...
# Calculating sentiment for text: "Today, B2B Buyers are not wai...
# Calculating sentiment for text: It’s easy to act like industry...
# Calculating sentiment for text: "Not every new idea is a good ...
# Calculating sentiment for text: "The world doesn’t need more c...
# Calculating sentiment for text: "Most businesses have plenty o...
# Calculating sentiment for text: "From visual content marketing...
# Calculating sentiment for text: "The abundance of information ...
# Calculating sentiment for text: "Starting a new content projec...
# Calculating sentiment for text: "How did a massive company lik...
# Calculating sentiment for text: "It is entirely possible for a...
# Calculating sentiment for text: "The more you can evolve your ...
# Calculating sentiment for text: "Ask a graphic designer about ...
# Calculating sentiment for text: "We are each entitled to our o...
# ...
# Calculating sentiment for text: Pre-Birthday Charity Post
#
# My ...
# Calculating sentiment for text: Post-birthday Thoughts About L...
# Calculating sentiment for text: Being in the middle of a holid...
# Calculating sentiment for text: Last week I took the CAIA (Cha...
# Calculating sentiment for text: Attended the Forbes Women’s Su...
# Calculating sentiment for text: Went to the Rise Up summit org...
# Calculating sentiment for text: I went to Bitcoin Amsterdam co...
# Calculating sentiment for text: I’m excited about Bitcoin reac...
# Calculating sentiment for text: 🎤 Excited to announce my parti...
# Calculating sentiment for text: Web3 events in Europe which I ...
# Calculating sentiment for text: There is a reason why most of ...
# Calculating sentiment for text: Yesterday I became an IMD alum...
# Calculating sentiment for text: Big News: I’m Launching a Shir...
# Calculating sentiment for text: Some time ago I met Daniella a...
# Calculating sentiment for text: ✨ Just got back from START Glo...
# Calculating sentiment for text: Yesterday I went to Founders D...
# Calculating sentiment for text: Honored to deliver the keynote...
# Calculating sentiment for text: Yesterday I had the honor of p...
# Calculating sentiment for text: Call for tech conference/event...
# Calculating sentiment for text: May is the conference season i...
# Calculating sentiment for text: On the rise of micro communiti...
# Calculating sentiment for text: I went to Forbes Swiss Money S...
# Calculating sentiment for text: I am making my Web3 Lifestyle ...
# Calculating sentiment for text: I just dropped a new video as ...
# Calculating sentiment for text: 🚀 New Episode Alert – Web3 Fil...
# Calculating sentiment for text: 📣 New YouTube Episode is LIVE!...
# Calculating sentiment for text: 💻 New YouTube Drop! | Web3 Bro...
# Calculating sentiment for text: Exploring Global Money Transfe...
# Calculating sentiment for text: Another day, another web3 vide...
# Calculating sentiment for text: 🏃‍♀️ Fitness Meets Web3
#
# I tes...
# Calculating sentiment for text: 🎶 New Episode: Investing in Mu...
# Calculating sentiment for text: 🌍 Can Blockchain Help Fight Cl...
# Calculating sentiment for text: 📫 Email, Reimagined for the We...
# Calculating sentiment for text: 🚀 Decentralized Finance: Wealt...
# Calculating sentiment for text: If you are in Geneva or around...
# Calculating sentiment for text: When I have read that José Par...
# Calculating sentiment for text: DFINITY is organizing the Worl...
# Calculating sentiment for text: Celebrating 4 Years of Interne...
# Calculating sentiment for text: There is a topic that consiste...
# Calculating sentiment for text: Today marks exactly 3 months s...
# Calculating sentiment for text: WEB3 GIVEAWAY by Web3 Lifestyl...
# Calculating sentiment for text: We are just a couple of week a...
# Calculating sentiment for text: I went to a LEAN IN Zürich (@l...
# Calculating sentiment for text: "I already know enough people,...
# Calculating sentiment for text: I went to a meetup on Future-p...
# Calculating sentiment for text: Art Basel 2025
#
# Another privil...
# Calculating sentiment for text: Yesterday I went to a Summer S...
# Calculating sentiment for text: EthCC Cannes Day 1
#
# Not sure w...
# Calculating sentiment for text: -Do you love graphs/charts/sta...
# Calculating sentiment for text: I went to my first hackathon t...
# Calculating sentiment for text: If you really want to know web...
# Calculating sentiment for text: On innovation in fashion or Et...
# Calculating sentiment for text: My 5 cents on EthCC and Notes ...
# Calculating sentiment for text: I am starting a bootcamp on ap...
# Calculating sentiment for text: Today I have discovered Founde...
# Calculating sentiment for text: Web3 might have a chance in ma...
# Calculating sentiment for text: I was dreaming of this product...
# Calculating sentiment for text: 3 widespread expressions I wis...
# Calculating sentiment for text: Good things should be shared, ...
# Calculating sentiment for text: The most difficult part of "bu...
# Calculating sentiment for text: Went to Vibe Code Fest yesterd...
# Calculating sentiment for text: This Friday stay tuned for a n...
# Calculating sentiment for text: And just like that, the first ...
# Calculating sentiment for text: 🚀 Episode 2 of the Present Per...
# Calculating sentiment for text: Swiss Startup Fundamentals tha...
# Calculating sentiment for text: Hackathons are becoming addict...
# Calculating sentiment for text: 🚀 Episode 3 of the Present Per...
# Calculating sentiment for text: Forbes Swiss Women Summit 2025...
# Calculating sentiment for text: We got the 2nd place at Startu...
# Calculating sentiment for text: 🚀 Episode 4 of the Present Per...
# Calculating sentiment for text: 🚀 Episode 5 of the Present Per...
# Calculating sentiment for text: Coming to Lugano's Plan ₿ is l...
# Calculating sentiment for text: What do Bob Dylan, Dee Dee Bri...
# Calculating sentiment for text: I’m happy to share that I’ve o...
# Calculating sentiment for text: I am going to the Startup Nigh...
# Calculating sentiment for text: The speed of product reinventi...
# Calculating sentiment for text: Imagine 4k+ entrepreneurially-...
# Calculating sentiment for text: Forbes Swiss Assetization Lead...
# Calculating sentiment for text: How can we be happy(ier) at wo...
# Calculating sentiment for text: Finding your courage - how to ...
# Calculating sentiment for text: AI Agents have their own assoc...
# Calculating sentiment for text: Is your memory actually “bad” ...
# Calculating sentiment for text: How being too self-confident c...
# Calculating sentiment for text: I thought December is a quite ...
# Calculating sentiment for text: I'm very proud to work at Ergo...
# Calculating sentiment for text: Wir suchen Verstärkung! #job  ...
# Calculating sentiment for text: Wir suchen ganz viele neue Arb...
# Calculating sentiment for text: Ever had a client saying:"Our ...
# Calculating sentiment for text: I've been a very happy Revolut...
# Calculating sentiment for text: Wir suchen nach Verstärkung! P...
# Calculating sentiment for text: Ich gebe einen ersten Einblick...
# Calculating sentiment for text: Something funny to lighten up ...
# Calculating sentiment for text: How to Stop Holding Yourself B...
# Calculating sentiment for text: Hi LinkedIn 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi friends 👋
#
# Scandit is looki...
# Calculating sentiment for text: Hi everyone 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi LinkedIn 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi LinkedIn 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi LinkedIn 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi LinkedIn 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi LinkedIn 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi LinkedIn 👋
#
# Scandit is look...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: Hi LinkedIn-Network 👋
#
# Scandit...
# Calculating sentiment for text: We launched a new product - Sc...
# Calculating sentiment for text: Great news to share! This will...
# Calculating sentiment for text: Die Freude war ganz auf meiner...
# Calculating sentiment for text: Many might think that UX is re...
# Calculating sentiment for text: ⚡️ What if we could have data ...
# Calculating sentiment for text: I'm excited to announce that N...
# Calculating sentiment for text: I'm so excited to announce tha...
# Calculating sentiment for text: I had a blast presenting on un...
# Calculating sentiment for text: 💭 Imagine this: a no-code #app...
# Calculating sentiment for text: I’m happy to share that I’m st...
# Calculating sentiment for text: 📢 Excited to announce that I'l...
# Calculating sentiment for text: Excited to kick off a new jour...
# Calculating sentiment for text: I’m happy to share that I’ve b...
# Calculating sentiment for text: Bereit für Innovation, aber di...
# Calculating sentiment for text: Excited to have completed the ...
# Calculating sentiment for text: Liebe Community,
#
# Mein Kollege...
# Calculating sentiment for text: The speed at which things evol...
# Calculating sentiment for text: Heute durfte ich im Rahmen des...
# Calculating sentiment for text: Gestern war wieder Jurytag bei...
# Calculating sentiment for text: Tonight I had the pleasure of ...
# Calculating sentiment for text: Seit ich dank meiner Frau selb...
# Calculating sentiment for text: I think it’s time I share one ...
# Calculating sentiment for text: Ich hatte wirklich grossen Spa...
# Calculating sentiment for text: Earlier this week, I shared ho...
# Calculating sentiment for text: I’m curious to see how the par...
# Calculating sentiment for text: Just finished the course “Bloc...
# Calculating sentiment for text: I’m happy to share that I have...
# Calculating sentiment for text: #hiring
# Schaut diese Stelle al...
# Calculating sentiment for text: Ich habe gerade den Kurs „Link...
# Calculating sentiment for text: Ich brauche eine neue Software...
# Calculating sentiment for text: Have a look at this impressive...
# Calculating sentiment for text: Ich habe einen neuen Job und a...
# Calculating sentiment for text: Warum kosten Interimsmanager m...
# Calculating sentiment for text: Ist das real? Oder ein Gedanke...
# Calculating sentiment for text: Wer möchte zum Team stossen, w...
# Calculating sentiment for text: Wir gehören zur Firma. Doch we...
# Calculating sentiment for text: Müssen Sie Ihrer Software auch...
# Calculating sentiment for text: Wie viele Fenster öffnet Ihre ...
# Calculating sentiment for text: Haben Sie auch Software, die e...
# Calculating sentiment for text: Hans hilft immer, die Software...
# Calculating sentiment for text: Wie wir gelernt haben, mit Cha...
# Calculating sentiment for text: Ungeeignete Software –
# 𝗞𝗲𝗻𝗻𝗲𝗻...
# Calculating sentiment for text: 𝗪𝗶𝗲 𝗮𝗹𝘁𝗲 𝗛𝗮𝗿𝗱- 𝘂𝗻𝗱 𝗦𝗼𝗳𝘁𝘄𝗮𝗿𝗲 𝗜𝗵...
# Calculating sentiment for text: Wie alte Hard- und Software Ih...
# Calculating sentiment for text: Nutzen Sie die Welt der 𝗚𝗶𝗴 𝗘𝗰...
# Calculating sentiment for text: Ich möchte etwas voranbringen....
# Calculating sentiment for text: 𝗠𝗲𝗶𝗻𝗲 𝗧𝗶𝗽𝗽𝘀 𝘇𝘂𝗿 𝗽𝗲𝗿𝘀ö𝗻𝗹𝗶𝗰𝗵𝗲𝗻 𝗘...
# Calculating sentiment for text: Früher habe ich beim Umsteigen...
# Calculating sentiment for text: Projektübergabe:
# Wenn aus Koll...
# Calculating sentiment for text: Ina Peters stellt ein (#hiring...
# Calculating sentiment for text: Die 𝘦𝘳𝘧𝘰𝘭𝘨𝘳𝘦𝘪𝘤𝘩𝘦 Projektüberga...
# Calculating sentiment for text: Projekt on track? Diese fünf W...
# Calculating sentiment for text: Die Kuh Elsa erklärt Problemur...
# Calculating sentiment for text: Kunden wünschen Vielfalt
# Unter...
# Calculating sentiment for text: Direkt Wirkung erzielen.
# Gilt...
# Calculating sentiment for text: Micha Knaus stellt ein (#hirin...
# Calculating sentiment for text: 𝗩𝗲𝗿ä𝗻𝗱𝗲𝗿𝘂𝗻𝗴 𝗱𝘂𝗹𝗱𝗲𝘁 𝗸𝗲𝗶𝗻𝗲𝗻 𝗔𝘂𝗳𝘀...
# Calculating sentiment for text: 𝗕𝗿𝗮𝘂𝗰𝗵𝘁 𝗲𝘀 𝗲𝗶𝗻 𝗗𝗶𝗽𝗹𝗼𝗺, 𝘂𝗺 𝗱𝗶𝗲 ...
# Calculating sentiment for text: 𝟲:𝟬𝟬 𝗨𝗵𝗿. 𝗡𝗲𝘂𝗲𝘀 𝗠𝗮𝗻𝗮𝗴𝗲𝗺𝗲𝗻𝘁 𝗘𝘅𝗲...
# Calculating sentiment for text: 𝗥𝗲𝘁𝘂𝗿𝗻 𝗼𝗳 𝗜𝗻𝘃𝗲𝘀𝘁𝗺𝗲𝗻𝘁 𝗲𝗶𝗻𝗲𝗿 𝗟𝗘𝗔...
# Calculating sentiment for text: Zwei Laptops. Gleiche Aufgabe....
# Calculating sentiment for text: Warum Interimsmanager sich rec...
# Calculating sentiment for text: Guten Morgen miteinander
# Ich d...
# Calculating sentiment for text: Tendenz zur Muttersprache durc...
# Calculating sentiment for text: Ein Mythos in der Produktion: ...
# Calculating sentiment for text: 𝗪𝗶𝗲 𝗮𝗹𝘁𝗲 𝗛𝗮𝗿𝗱- 𝘂𝗻𝗱 𝗦𝗼𝗳𝘁𝘄𝗮𝗿𝗲 𝗜𝗵...
# Calculating sentiment for text: 𝗩𝗲𝗿𝗮𝗹𝘁𝗲𝘁𝗲 𝗣𝗿𝗼𝗱𝘂𝗸𝘁𝗶𝗼𝗻𝘀𝘀𝗼𝗳𝘁𝘄𝗮𝗿𝗲 ...
# Calculating sentiment for text: Die neue Software steht zur Ve...
# Calculating sentiment for text: Glad I could participate on th...
# Calculating sentiment for text: Technische Schulden: unsichtba...
# Calculating sentiment for text: Mein grösstes Learning aus dem...
# Calculating sentiment for text: Dies gelesen: 𝘱𝘳𝘰𝘧𝘪𝘤𝘪𝘦𝘯𝘵 𝘪𝘯 𝘤𝘰...
# Calculating sentiment for text: Equipment-Erneuerung in der Pr...
# Calculating sentiment for text: Equipment-Erneuerung:
# 3 Praxis...
# Calculating sentiment for text: Equipment-Erneuerung in der Pr...
# Calculating sentiment for text: Wann haben Sie das letzte Mal
# ...
# Calculating sentiment for text: Ich habe einen CIO interviewed...
# Calculating sentiment for text: Ich durfte viele IT-Projekte b...
# Calculating sentiment for text: Denkfehler passieren uns allen...
# Calculating sentiment for text: Die Karriere führt mich in ein...
# Calculating sentiment for text: Gute Struktur entscheidet bei ...
# Calculating sentiment for text: Ich habe ein neues Angebot auf...
# Calculating sentiment for text: “Negotiations are a life skill...
# Calculating sentiment for text: Bevor ich entscheide, höre ich...
# Calculating sentiment for text: Entwickeln sich LLMs zu einer ...
# Calculating sentiment for text: 𝗣𝗿𝗼𝗺𝗽𝘁-𝘁𝗼-𝗔𝗽𝗽
# Ein Erfahrungsbe...
# Calculating sentiment for text: 𝗣𝗿𝗼𝗺𝗽𝘁-𝘁𝗼-𝗔𝗽𝗽
# Der Erfahrungsbe...
# Calculating sentiment for text: KI hier, Jobänderung dort
# Waru...
# Calculating sentiment for text: Eine spannende Tagung zum Them...
# Calculating sentiment for text: Eine Datei.
# In welches der mög...
# Calculating sentiment for text: Wie lange lebt Produktions-Sof...
# Calculating sentiment for text: Erneuerung der Produktions-Sof...
# Calculating sentiment for text: Viele Leute und eine grossarti...
# Calculating sentiment for text: Produktivität steigern!
# Für ei...
# Calculating sentiment for text: Gegen Ende des Projekts führen...
# Calculating sentiment for text: Wer ist das am schnellsten
# gew...
# Calculating sentiment for text: Wer in der Elektronikfertigung...
# Calculating sentiment for text: Wenn interne Tools in 10 Minut...
# Calculating sentiment for text: 2001 war ich mitten im Dot-Com...
# Calculating sentiment for text: 𝗟𝗲𝗮𝗱 𝟮𝟲
# Leadership ist heute w...
# Calculating sentiment for text: 𝗗𝗶𝗲 𝗔𝘂𝘁𝗼𝗺𝗮𝘁𝗶𝘀𝗶𝗲𝗿𝘂𝗻𝗴𝘀𝗽𝘆𝗿𝗮𝗺𝗶𝗱𝗲
# W...
# Calculating sentiment for text: Meine Software-Lösung ist zu k...
# Calculating sentiment for text: Als Interimsmanager musst du
# ...
# Calculating sentiment for text: Call for Speaker
# Future Sympos...
# Calculating sentiment for text: Unstrukturierte Produktionsdat...
# Calculating sentiment for text: KI gibt es seit 1960.
# Hinter ...
# Calculating sentiment for text: Vom System generierte
# Test-Phi...
# Calculating sentiment for text: Eine neue Aufgabe!
# Eine Rolle,...
# Calculating sentiment for text: Wer führt den Prozess?
# Das Man...
# Calculating sentiment for text: Als CEO müssen Sie kein IT-Spe...
# Calculating sentiment for text: Der Swiss Smart Factory Open D...
# Calculating sentiment for text: Zertifikat abgeschlossen
# im So...
# Calculating sentiment for text: ERP, MES, PLM sind bekannt.
# Wa...
# Calculating sentiment for text: 12 Mythen für IT-Projekte:
# Ein...
# Calculating sentiment for text: SaaS ohne klare Preise?
# Ein pr...
# Calculating sentiment for text: Die Festtage erinnern daran, w...
#
# SUCCESS: Enriched dataset saved to ../data/Raw_Dataset_LinkedIn.csv
# Preview of sentiment score.
#                                            Post Content  Sentiment Score
# 6477  “Humanity will have a successor.” Sam Ginn on ...              1.0
# 6476  This is a great opportunity with a great company!              1.0
# 6475  Looking for a challenge in a fast-paced tradin...              0.5
# 6474  I am thrilled to have joined UBP - Union Banca...              1.0
# 6473  We need both: privacy and health! In a spirit ...              1.0
#
# Preview of top Alignment scores:
#                                            Post Content  Semantic Alignment
# 6515  🚀 Digitalisierung & KI für KMUs: Praxisnahe Er...            0.835944
# 8227  🔍 Resilienz ist keine Nebensache mehr – sie wi...            0.830111
# 6398  ✦ Day 18 of building in public ✦\n\nEveryone's...            0.808895
# 8244  Stell dir vor, du bist wie Bambus im Sturm.\nD...            0.799892
# 8205  Kompetenz zeigt sich nicht, wenn alles läuft –...            0.776590
